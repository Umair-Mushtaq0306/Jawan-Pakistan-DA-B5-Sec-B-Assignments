# %% [raw]
# Assignment 1
# Q1. Write a program that takes two numbers (a = 15 , b = 4) and prints their:
#
# Sum

# %%
a = 15

# %%
b = 4

# %%
a+b # sum
# Out:
# 19

# %%
Difference

# %%
a-b
# Out:
# 11

# %% [raw]
# Product *

# %%
a*b
# Out:
# 60

# %% [raw]
# Division

# %%
a/b
# Out:
# 3.75

# %% [raw]
# Floor Division

# %%
a//b
# Out:
# 3

# %% [raw]
# Modulus

# %%
a%b
# Out:
# 3

# %% [raw]
# Q2. Write a code to store your favorite food in a variable and print it.

# %%
Fav_Food="Burger"

# %%
print(Fav_Food)
# Out:
# Burger

# %% [raw]
# Q3. "I have 22 apples and 33 mangoes. How many fruits do I have in total?"
#
# apple = '22'
#
# mangoes = 33

# %%
apple = 22

# %%
mangoes = 33

# %%
Total = apple + mangoes

# %%
Total
# Out:
# 55

# %% [raw]
# Q4. Check the type and convert: (num1 = 10, num2 = 5.6, num3 = 4.43, num4='23')
#
# Integer to float
#
# Float to integer
#
# Float to String
#
# String to Integer

# %%
num1 = 10
num2 = 5.6
num3 = 4.43
num4 = '23'

# %%
print("num1:", num1, type(num1))
# Out:
# num1: 10 <class 'int'>

# %%
print("num2:", num2, type(num2))
# Out:
# num2: 5.6 <class 'float'>

# %%
print("num3:", num3, type(num3))
# Out:
# num3: 4.43 <class 'float'>

# %%
print("num4:", num4, type(num4))
# Out:
# num4: 23 <class 'str'>

# %%
print(float(num1))
print(float(num2))
print(float(num3))
print(float(num4))
# Out:
# 10.0
# 5.6
# 4.43
# 23.0

# %%
print(int(num1))
print(int(num2))
print(int(num3))
print(int(num4))
# Out:
# 10
# 5
# 4
# 23

# %%
print(str(num1))
print(str(num2))
print(str(num3))
print(str(num4))
# Out:
# 10
# 5.6
# 4.43
# 23

# %%
print(int(num1))
print(int(num2))
print(int(num3))
print(int(num4))
# Out:
# 10
# 5
# 4
# 23

# %% [raw]
# Q5. Store in a varibale: Write Your name , Your age, Add 1 to your age using a variable, Print final age

# %%
name = "Umair Mushtaq"

# %%
name
# Out:
# 'Umair Mushtaq'

# %%
Age = 28

# %%
Final_Age = Age+1

# %%
print(Final_Age)
# Out:
# 29

# %%
Q6.

a = 2

b = 1

c = 6

d = 3

Add a and b

Subtract c and a

Multiply d and b

Divide c and d (float division)

Find modulus of c divided by d

Square of (d+a)

# %%
a = 2
b = 1
c = 6
d = 3

# %%
(a+b) # add
# Out:
# 3

# %%
(c-a) #sub
# Out:
# 4

# %%
(d*b)
# Out:
# 3

# %%
(c/d) #float
# Out:
# 2.0

# %%
c%d
# Out:
# 0

# %%
(d+a)**2
# Out:
# 25

# %% [raw]
# Q7.
#
# You were 20 years old in the year 2020. Now add 5 more years to your age. What is your current age now?
#
# Store age in a variable called age. Print final output in same variable

# %%
age = 20

# %%
age = 20 +5

# %%
age
# Out:
# 25

# %% [raw]
# Q8.
#
# a = '2'
#
# b = '11'
#
# c = 6.3
#
# Convert a to integer then add to c
#
# Convert b to float then multiply by c
#
# Convert c to integer then add to c

# %%
a='2'
b='11'
c=6.3

# %%
int(a)+c
# Out:
# 8.3

# %%
float(b)*c
# Out:
# 69.3

# %%
int(c)+c
# Out:
# 12.3

# %% [raw]
# Q9.
#
# You had 12 books, and you gave 4 to your friend. How many books do you have now?
#
# Store books in a variable called books. Print final output in same variable

# %%
books = 12

# %%
books = 12-4

# %%
print(books)
# Out:
# 8

# %% [raw]
# Q10.
#
# You baked 5 cookies. You baked 3 times more cookies today. How many cookies did you bake today?
#
# Store cookies in a variable called cookies. Print final output in same variable

# %%
cookies = 5

# %%
cookies = 5*3

# %%
print(cookies)
# Out:
# 15

# %% [raw]
# Q11. Solve the following expression using PEDMAS:
# 20 - 4 × (3 + 2) + 18 ÷ 3

# %%
# Solve using PEDMAS (Parentheses, Exponents, Division/Multiplication, Addition/Subtraction)

# %%
expr = 20 - 4 * (3 + 2) + 18 / 3

# %%
expr
# Out:
# 6.0
