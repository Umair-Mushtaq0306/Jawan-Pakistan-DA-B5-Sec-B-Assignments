# %% [markdown]
# #### Question 1
#
# ##### Calculate and write the output of the following expression:
# **30 + 4 × 3 − 6**

# %%
expr = 30+4*3-6
expr
# Out:
# 36

# %% [markdown]
# #### Question 2
#
# ##### Calculate and write the output of the following expression:
# **100 ÷ 4 + 7 − 5**

# %%
expr1 = 10/4+7-5
expr1
# Out:
# 4.5

# %% [markdown]
# #### Question 3
#
# ##### Create a variable containing the string value "100". Convert it into an integer and display its data type before and after conversion.

# %%
string_value = "100"
int_value = int(string_value)
print("Before conversion:", type(string_value))
print("After conversion:", type(int_value))
# Out:
# Before conversion: <class 'str'>
# After conversion: <class 'int'>

# %% [markdown]
# #### Question 4
#
# ##### Create the following list and display:
# ##### cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]
# ##### Second city
# ##### Fourth city

# %%
cities = ["Karachi", "Lahore", "Islamabad", "Peshawar", "Quetta"]

# %%
print("Second city:", cities[1])
print("Fourth city:", cities[3])
# Out:
# Second city: Lahore
# Fourth city: Peshawar

# %% [markdown]
# #### Question 5
# ##### Create the following nested list and display:
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Ali
# ##### Ayesha

# %%
students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
print(students[0][0])
print(students[1][0])
# Out:
# Ali
# Ayesha

# %% [markdown]
# #### Question 6
# ##### Given list:
# ##### numbers = [10, 20, 30, 40, 50, 60, 70]
# ##### Display:
# ##### First 3 elements
# ##### Last 3 elements

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]
print(numbers[0:3])
print(numbers[4:])
# Out:
# [10, 20, 30]
# [50, 60, 70]

# %% [markdown]
# #### Question 7
# ##### Given nested list::
# ##### students = [["Ali", 20], ["Ayesha", 22], ["Ahmed", 21]]
# ##### Display:
# ##### Name of first student
# ##### Age of second student

# %%
print(students[0][0])
print(students[1][1])
# Out:
# Ali
# 22

# %% [markdown]
# #### Question 8
# ##### Create a list of 5 fruits and display:
# ##### First fruit
# ##### Last fruit

# %%
Fruit_list = ["Mango","Apple","Strawberry","Banana","Orange"]
print(Fruit_list[0])
print(Fruit_list[-1])
# Out:
# Mango
# Orange

# %% [markdown]
# #### Question 9
# ##### Create the following list and display:
# ##### colors = ["Red", "Blue", "Green", "Yellow", "Black"]
# ##### First color
# ##### Last color
# ##### using negative indexing

# %%
colors = ["Red", "Blue", "Green", "Yellow", "Black"]
print(colors[-5])
print(colors[-1])
# Out:
# Red
# Black

# %% [markdown]
# #### Question 10
# ##### Given nested list:
# ##### marks = [["Math", 90], ["Physics", 85], ["English", 88]]
# ##### Display:
# ##### Subject of second student
# ##### Marks of third student

# %%
marks = [["Math", 90], ["Physics", 85], ["English", 88]]
print(marks[1][0])
print(marks[2][1])
# Out:
# Physics
# 88
